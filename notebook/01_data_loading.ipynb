# %%
! pip install kaggle
# Out:
# Requirement already satisfied: kaggle in d:\users\hp\anaconda3\lib\site-packages (2.2.0)
# Requirement already satisfied: bleach in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (6.3.0)
# Requirement already satisfied: jupytext in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (1.19.3)
# Requirement already satisfied: kagglesdk<1.0,>=0.1.24 in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (0.1.27)
# Requirement already satisfied: packaging in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (25.0)
# Requirement already satisfied: protobuf in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (5.29.3)
# Requirement already satisfied: python-dateutil in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (2.9.0.post0)
# Requirement already satisfied: python-slugify in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (8.0.4)
# Requirement already satisfied: requests in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (2.32.5)
# Requirement already satisfied: tqdm in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (4.67.1)
# Requirement already satisfied: urllib3>=1.15.1 in d:\users\hp\anaconda3\lib\site-packages (from kaggle) (2.5.0)
# Requirement already satisfied: webencodings in d:\users\hp\anaconda3\lib\site-packages (from bleach->kaggle) (0.5.1)
# Requirement already satisfied: markdown-it-py>=1.0 in d:\users\hp\anaconda3\lib\site-packages (from jupytext->kaggle) (2.2.0)
# Requirement already satisfied: mdit-py-plugins in d:\users\hp\anaconda3\lib\site-packages (from jupytext->kaggle) (0.5.0)
# Requirement already satisfied: nbformat in d:\users\hp\anaconda3\lib\site-packages (from jupytext->kaggle) (5.10.4)
# Requirement already satisfied: pyyaml in d:\users\hp\anaconda3\lib\site-packages (from jupytext->kaggle) (6.0.3)
# Requirement already satisfied: mdurl~=0.1 in d:\users\hp\anaconda3\lib\site-packages (from markdown-it-py>=1.0->jupytext->kaggle) (0.1.2)
# Requirement already satisfied: fastjsonschema>=2.15 in d:\users\hp\anaconda3\lib\site-packages (from nbformat->jupytext->kaggle) (2.21.2)
# Requirement already satisfied: jsonschema>=2.6 in d:\users\hp\anaconda3\lib\site-packages (from nbformat->jupytext->kaggle) (4.25.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in d:\users\hp\anaconda3\lib\site-packages (from nbformat->jupytext->kaggle) (5.8.1)
# Requirement already satisfied: traitlets>=5.1 in d:\users\hp\anaconda3\lib\site-packages (from nbformat->jupytext->kaggle) (5.14.3)
# Requirement already satisfied: attrs>=22.2.0 in d:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in d:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in d:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.37.0)
# Requirement already satisfied: rpds-py>=0.7.1 in d:\users\hp\anaconda3\lib\site-packages (from jsonschema>=2.6->nbformat->jupytext->kaggle) (0.28.0)
# Requirement already satisfied: platformdirs>=2.5 in d:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (4.5.0)
# Requirement already satisfied: pywin32>=300 in d:\users\hp\anaconda3\lib\site-packages (from jupyter-core!=5.0.*,>=4.12->nbformat->jupytext->kaggle) (311)
# Requirement already satisfied: six>=1.5 in d:\users\hp\anaconda3\lib\site-packages (from python-dateutil->kaggle) (1.17.0)
# Requirement already satisfied: text-unidecode>=1.3 in d:\users\hp\anaconda3\lib\site-packages (from python-slugify->kaggle) (1.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\users\hp\anaconda3\lib\site-packages (from requests->kaggle) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in d:\users\hp\anaconda3\lib\site-packages (from requests->kaggle) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in d:\users\hp\anaconda3\lib\site-packages (from requests->kaggle) (2026.1.4)
# Requirement already satisfied: colorama in d:\users\hp\anaconda3\lib\site-packages (from tqdm->kaggle) (0.4.6)

# %%
#configure the path of kaggle.json
# !mkdir %USERPROFILE%\.kaggle
# Out:
# A subdirectory or file C:\Users\hp\.kaggle already exists.

# %%
# !copy kaggle.json %USERPROFILE%\.kaggle\
# Out:
#         1 file(s) copied.

# %%
# !kaggle datasets list
# Out:
# ref                                                                    title                                                  size  lastUpdated                 downloadCount  voteCount  usabilityRating
# ---------------------------------------------------------------------  -----------------------------------------------  ----------  --------------------------  -------------  ---------  ---------------
# laveshjadon/ai-impact-on-students                                      Impact of Ai on Students                            1187170  2026-05-10 23:12:10.070000           5094        130                1
# muhammadwaqas023/ai-impact-in-future-on-jobs-market-in-2030            Ai Impact in future on jobs market in 2030           108338  2026-05-24 15:12:54.047000           1446         38                1
# divyjain28/superstore-sales                                            Superstore Sales Analysis                           1579499  2026-05-15 08:16:38.500000            946         27                1
# algozee/teenager-menthal-healy                                         Social Media Impact on Teen Mental Health             16190  2026-04-05 08:04:21.823000          36693        759                1
# lucalullo/housing-affordability-26-countries-1975-2025                 housing-affordability-26-countries-1975-2025          21521  2026-05-24 14:02:18.800000            481         26                1
# shambhurajejagadale/student-performance-prediction-dataset             Student Performance Prediction Dataset                84282  2026-05-09 15:49:58.877000           3499         86                1
# sanyamdhadiwal2302/netflix-data                                        Netflix Data                                        1783607  2026-05-22 18:10:36.380000           1510         38        0.9411765
# shyamnadhs/heart-disease-prediction-dataset                            Heart disease prediction dataset                      16480  2026-05-27 17:08:10.520000            761         24        0.8235294
# laveshjadon/ai-impact-on-human-mental-growth                           Impact of Ai on Human Mental Growth                 3323782  2026-05-23 09:36:48.597000            350         23                1
# emirhanakku/e-commerce-order-risk-classification-dataset               E-Commerce Order Risk Classification Dataset         360389  2026-05-26 02:56:16.513000            822         29                1
# shambhurajejagadale/student-placement-and-career-success-dataset-2026  Student Placement & Career Success Dataset 2026     1410717  2026-05-27 10:25:16.853000            688         28                1
# abbas829/global-superstore-sales-dataset                               Global Superstore Sales Dataset                     2814050  2026-05-23 00:41:54.710000            718         23                1
# aryanmdev/world-gym-and-fitness-trends-20002026                        World Gym & Fitness Trends (2000–2026)              1948795  2026-05-23 10:20:58.380000            686         33                1
# lightningxyz/student-performance-dataset                               Student Performance & Lifestyle Dataset               26251  2026-05-03 04:18:33.083000            748         26                1
# noopurbhatt/retail-store-sales-forecasting-dataset                     Retail Store Sales Forecasting Dataset              2881615  2026-05-16 18:20:47.867000           1027         29        0.9411765
# zynicide/wine-reviews                                                  Wine Reviews                                       53336293  2017-11-27 17:08:04.700000         354209       3870        0.7941176
# nolanbconaway/pitchfork-data                                           18,393 Pitchfork Reviews                           34891456  2017-01-13 04:18:10.113000          17988        459        0.7058824
# rishikeshjani/perch-onnx-for-birdclef-2026                             Perch-onnx-for-birdclef+2026                      395240323  2026-03-30 07:07:25.863000           1954         20       0.47058824
# datasnaek/youtube-new                                                  Trending YouTube Video Statistics                 210575746  2019-06-03 00:56:47.177000         305641       5929        0.7941176
# jpmiller/publicassistance                                              US Public Food Assistance 1 - WIC                    304041  2023-04-17 20:01:05.960000          26389        511        0.9411765

# %%
#API to fetch dataset from kaggle
# !kaggle datasets download -d kazanova/sentiment140
# Out:
# Dataset URL: https://www.kaggle.com/datasets/kazanova/sentiment140
# License(s): other
# sentiment140.zip: Skipping, found more recently modified local copy (use --force to force download)

# %%
# extracting the compressed ddata 
from zipfile import ZipFile
dataset = 'sentiment140.zip'

with ZipFile(dataset,'r') as zip: 
    zip.extractall()
    print('The dataset is extracted')
# Out:
# The dataset is extracted
